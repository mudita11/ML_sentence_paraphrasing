# %% [markdown]
# <a href="https://colab.research.google.com/github/mudita11/ML_sentence_paraphrasing/blob/master/GPT_2_Sent_Para.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip gpt-2-simple.zip
# Out:
# Archive:  gpt-2-simple.zip
#    creating: gpt-2-simple/
#   inflating: __MACOSX/._gpt-2-simple
#   inflating: gpt-2-simple/.DS_Store
#   inflating: __MACOSX/gpt-2-simple/._.DS_Store
#   inflating: gpt-2-simple/LICENSE
#   inflating: gpt-2-simple/requirements.txt
#   inflating: gpt-2-simple/train_data.txt
#   inflating: __MACOSX/gpt-2-simple/._train_data.txt
#   inflating: gpt-2-simple/MANIFEST.in
#    creating: gpt-2-simple/models/
#   inflating: __MACOSX/gpt-2-simple/._models
#    creating: gpt-2-simple/docs/
#   inflating: __MACOSX/gpt-2-simple/._docs
#   inflating: gpt-2-simple/README.md
#   inflating: gpt-2-simple/setup.py
#   inflating: gpt-2-simple/.gitignore
#    creating: gpt-2-simple/.github/
#   inflating: __MACOSX/gpt-2-simple/._.github
#   inflating: gpt-2-simple/generate_text.py
#   inflating: __MACOSX/gpt-2-simple/._generate_text.py
#    creating: gpt-2-simple/gpt-2/
#   inflating: __MACOSX/gpt-2-simple/._gpt-2
#   inflating: gpt-2-simple/training_data.txt
#   inflating: __MACOSX/gpt-2-simple/._training_data.txt
#    creating: gpt-2-simple/.git/
#   inflating: __MACOSX/gpt-2-simple/._.git
#    creating: gpt-2-simple/gpt_2_simple/
#   inflating: __MACOSX/gpt-2-simple/._gpt_2_simple
#    creating: gpt-2-simple/models/124M/
#   inflating: __MACOSX/gpt-2-simple/models/._124M
#   inflating: gpt-2-simple/docs/gen_demo.png
#   inflating: gpt-2-simple/.github/FUNDING.yml
#   inflating: gpt-2-simple/gpt-2/Dockerfile.cpu
#   inflating: gpt-2-simple/gpt-2/Dockerfile.gpu
#   inflating: gpt-2-simple/gpt-2/.DS_Store
#   inflating: __MACOSX/gpt-2-simple/gpt-2/._.DS_Store
#   inflating: gpt-2-simple/gpt-2/LICENSE
#   inflating: gpt-2-simple/gpt-2/requirements.txt
#   inflating: gpt-2-simple/gpt-2/model_card.md
#   inflating: gpt-2-simple/gpt-2/domains.txt
#    creating: gpt-2-simple/gpt-2/models/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/._models
#   inflating: gpt-2-simple/gpt-2/DEVELOPERS.md
#   inflating: gpt-2-simple/gpt-2/README.md
#   inflating: gpt-2-simple/gpt-2/.gitignore
#   inflating: gpt-2-simple/gpt-2/download_model.py
#   inflating: __MACOSX/gpt-2-simple/gpt-2/._download_model.py
#   inflating: gpt-2-simple/gpt-2/CONTRIBUTORS.md
#   inflating: gpt-2-simple/gpt-2/.gitattributes
#    creating: gpt-2-simple/gpt-2/.git/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/._.git
#    creating: gpt-2-simple/gpt-2/src/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/._src
#   inflating: gpt-2-simple/.git/config
#    creating: gpt-2-simple/.git/objects/
#   inflating: __MACOSX/gpt-2-simple/.git/._objects
#   inflating: gpt-2-simple/.git/HEAD
#    creating: gpt-2-simple/.git/info/
#   inflating: __MACOSX/gpt-2-simple/.git/._info
#    creating: gpt-2-simple/.git/logs/
#   inflating: __MACOSX/gpt-2-simple/.git/._logs
#   inflating: gpt-2-simple/.git/description
#    creating: gpt-2-simple/.git/hooks/
#   inflating: __MACOSX/gpt-2-simple/.git/._hooks
#    creating: gpt-2-simple/.git/refs/
#   inflating: __MACOSX/gpt-2-simple/.git/._refs
#   inflating: gpt-2-simple/.git/index
#   inflating: gpt-2-simple/.git/packed-refs
#   inflating: gpt-2-simple/.git/FETCH_HEAD
#   inflating: gpt-2-simple/gpt_2_simple/gpt_2.py
#   inflating: __MACOSX/gpt-2-simple/gpt_2_simple/._gpt_2.py
#   inflating: gpt-2-simple/gpt_2_simple/__init__.py
#    creating: gpt-2-simple/gpt_2_simple/__pycache__/
#   inflating: __MACOSX/gpt-2-simple/gpt_2_simple/.___pycache__
#    creating: gpt-2-simple/gpt_2_simple/src/
#   inflating: __MACOSX/gpt-2-simple/gpt_2_simple/._src
#   inflating: gpt-2-simple/models/124M/model.ckpt.meta
#   inflating: gpt-2-simple/models/124M/encoder.json
#   inflating: gpt-2-simple/models/124M/checkpoint
#   inflating: gpt-2-simple/models/124M/hparams.json
#   inflating: gpt-2-simple/models/124M/model.ckpt.index
#   inflating: gpt-2-simple/models/124M/model.ckpt.data-00000-of-00001
#   inflating: gpt-2-simple/models/124M/vocab.bpe
#    creating: gpt-2-simple/gpt-2/models/124M/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/models/._124M
#   inflating: gpt-2-simple/gpt-2/.git/config
#    creating: gpt-2-simple/gpt-2/.git/objects/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/.git/._objects
#   inflating: gpt-2-simple/gpt-2/.git/HEAD
#    creating: gpt-2-simple/gpt-2/.git/info/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/.git/._info
#    creating: gpt-2-simple/gpt-2/.git/logs/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/.git/._logs
#   inflating: gpt-2-simple/gpt-2/.git/description
#    creating: gpt-2-simple/gpt-2/.git/hooks/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/.git/._hooks
#    creating: gpt-2-simple/gpt-2/.git/refs/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/.git/._refs
#   inflating: gpt-2-simple/gpt-2/.git/index
#   inflating: gpt-2-simple/gpt-2/.git/packed-refs
#    creating: gpt-2-simple/gpt-2/src/__pycache__/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/src/.___pycache__
#   inflating: gpt-2-simple/gpt-2/src/encoder.py
#   inflating: gpt-2-simple/gpt-2/src/model.py
#   inflating: gpt-2-simple/gpt-2/src/sample.py
#   inflating: gpt-2-simple/gpt-2/src/interactive_conditional_samples.py
#   inflating: __MACOSX/gpt-2-simple/gpt-2/src/._interactive_conditional_samples.py
#   inflating: gpt-2-simple/gpt-2/src/generate_unconditional_samples.py
#   inflating: __MACOSX/gpt-2-simple/gpt-2/src/._generate_unconditional_samples.py
#    creating: gpt-2-simple/.git/objects/pack/
#   inflating: __MACOSX/gpt-2-simple/.git/objects/._pack
#    creating: gpt-2-simple/.git/objects/info/
#   inflating: gpt-2-simple/.git/info/exclude
#   inflating: gpt-2-simple/.git/logs/HEAD
#    creating: gpt-2-simple/.git/logs/refs/
#   inflating: __MACOSX/gpt-2-simple/.git/logs/._refs
#   inflating: gpt-2-simple/.git/hooks/commit-msg.sample
#   inflating: gpt-2-simple/.git/hooks/pre-rebase.sample
#   inflating: gpt-2-simple/.git/hooks/pre-commit.sample
#   inflating: gpt-2-simple/.git/hooks/applypatch-msg.sample
#   inflating: gpt-2-simple/.git/hooks/fsmonitor-watchman.sample
#   inflating: gpt-2-simple/.git/hooks/pre-receive.sample
#   inflating: gpt-2-simple/.git/hooks/prepare-commit-msg.sample
#   inflating: gpt-2-simple/.git/hooks/post-update.sample
#   inflating: gpt-2-simple/.git/hooks/pre-merge-commit.sample
#   inflating: gpt-2-simple/.git/hooks/pre-applypatch.sample
#   inflating: gpt-2-simple/.git/hooks/pre-push.sample
#   inflating: gpt-2-simple/.git/hooks/update.sample
#    creating: gpt-2-simple/.git/refs/heads/
#   inflating: __MACOSX/gpt-2-simple/.git/refs/._heads
#    creating: gpt-2-simple/.git/refs/tags/
#    creating: gpt-2-simple/.git/refs/remotes/
#   inflating: __MACOSX/gpt-2-simple/.git/refs/._remotes
#   inflating: gpt-2-simple/gpt_2_simple/__pycache__/gpt_2.cpython-37.pyc
#   inflating: gpt-2-simple/gpt_2_simple/__pycache__/__init__.cpython-37.pyc
#   inflating: gpt-2-simple/gpt_2_simple/src/accumulate.py
#   inflating: gpt-2-simple/gpt_2_simple/src/__init__.py
#    creating: gpt-2-simple/gpt_2_simple/src/__pycache__/
#   inflating: __MACOSX/gpt-2-simple/gpt_2_simple/src/.___pycache__
#   inflating: gpt-2-simple/gpt_2_simple/src/encoder.py
#   inflating: gpt-2-simple/gpt_2_simple/src/model.py
#   inflating: gpt-2-simple/gpt_2_simple/src/memory_saving_gradients.py
#   inflating: gpt-2-simple/gpt_2_simple/src/sample.py
#   inflating: gpt-2-simple/gpt_2_simple/src/load_dataset.py
#   inflating: gpt-2-simple/gpt-2/models/124M/model.ckpt.meta
#   inflating: gpt-2-simple/gpt-2/models/124M/events.out.tfevents.1596540824.muditas-MBP.lan
#   inflating: gpt-2-simple/gpt-2/models/124M/encoder.json
#   inflating: gpt-2-simple/gpt-2/models/124M/checkpoint
#   inflating: gpt-2-simple/gpt-2/models/124M/model-10.data-00000-of-00001
#   inflating: gpt-2-simple/gpt-2/models/124M/hparams.json
#   inflating: gpt-2-simple/gpt-2/models/124M/model-10.meta
#   inflating: gpt-2-simple/gpt-2/models/124M/model-10.index
#   inflating: gpt-2-simple/gpt-2/models/124M/counter
#   inflating: gpt-2-simple/gpt-2/models/124M/model.ckpt.index
#   inflating: gpt-2-simple/gpt-2/models/124M/model.ckpt.data-00000-of-00001
#   inflating: gpt-2-simple/gpt-2/models/124M/vocab.bpe
#    creating: gpt-2-simple/gpt-2/.git/objects/pack/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/.git/objects/._pack
#    creating: gpt-2-simple/gpt-2/.git/objects/info/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/.git/objects/._info
#   inflating: gpt-2-simple/gpt-2/.git/info/exclude
#   inflating: gpt-2-simple/gpt-2/.git/logs/HEAD
#    creating: gpt-2-simple/gpt-2/.git/logs/refs/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/.git/logs/._refs
#   inflating: gpt-2-simple/gpt-2/.git/hooks/commit-msg.sample
#   inflating: gpt-2-simple/gpt-2/.git/hooks/pre-rebase.sample
#   inflating: gpt-2-simple/gpt-2/.git/hooks/pre-commit.sample
#   inflating: gpt-2-simple/gpt-2/.git/hooks/applypatch-msg.sample
#   inflating: gpt-2-simple/gpt-2/.git/hooks/fsmonitor-watchman.sample
#   inflating: gpt-2-simple/gpt-2/.git/hooks/pre-receive.sample
#   inflating: gpt-2-simple/gpt-2/.git/hooks/prepare-commit-msg.sample
#   inflating: gpt-2-simple/gpt-2/.git/hooks/post-update.sample
#   inflating: gpt-2-simple/gpt-2/.git/hooks/pre-merge-commit.sample
#   inflating: gpt-2-simple/gpt-2/.git/hooks/pre-applypatch.sample
#   inflating: gpt-2-simple/gpt-2/.git/hooks/pre-push.sample
#   inflating: gpt-2-simple/gpt-2/.git/hooks/update.sample
#    creating: gpt-2-simple/gpt-2/.git/refs/heads/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/.git/refs/._heads
#    creating: gpt-2-simple/gpt-2/.git/refs/tags/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/.git/refs/._tags
#    creating: gpt-2-simple/gpt-2/.git/refs/remotes/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/.git/refs/._remotes
#   inflating: gpt-2-simple/gpt-2/src/__pycache__/sample.cpython-37.pyc
#   inflating: gpt-2-simple/gpt-2/src/__pycache__/model.cpython-37.pyc
#   inflating: gpt-2-simple/gpt-2/src/__pycache__/encoder.cpython-37.pyc
#   inflating: gpt-2-simple/.git/objects/pack/pack-47ea9926bcf3213326f4d8513dd89a908bac34fa.pack
#   inflating: gpt-2-simple/.git/objects/pack/pack-47ea9926bcf3213326f4d8513dd89a908bac34fa.idx
#    creating: gpt-2-simple/.git/logs/refs/heads/
#   inflating: __MACOSX/gpt-2-simple/.git/logs/refs/._heads
#    creating: gpt-2-simple/.git/logs/refs/remotes/
#   inflating: __MACOSX/gpt-2-simple/.git/logs/refs/._remotes
#   inflating: gpt-2-simple/.git/refs/heads/master
#    creating: gpt-2-simple/.git/refs/remotes/origin/
#   inflating: __MACOSX/gpt-2-simple/.git/refs/remotes/._origin
#   inflating: gpt-2-simple/gpt_2_simple/src/__pycache__/sample.cpython-37.pyc
#   inflating: gpt-2-simple/gpt_2_simple/src/__pycache__/model.cpython-37.pyc
#   inflating: gpt-2-simple/gpt_2_simple/src/__pycache__/encoder.cpython-37.pyc
#   inflating: gpt-2-simple/gpt_2_simple/src/__pycache__/memory_saving_gradients.cpython-37.pyc
#   inflating: gpt-2-simple/gpt_2_simple/src/__pycache__/load_dataset.cpython-37.pyc
#   inflating: gpt-2-simple/gpt_2_simple/src/__pycache__/accumulate.cpython-37.pyc
#   inflating: gpt-2-simple/gpt_2_simple/src/__pycache__/__init__.cpython-37.pyc
#   inflating: gpt-2-simple/gpt-2/.git/objects/pack/pack-b661491ab1eccbdc864e0f14cadbe68bf8df677a.pack
#   inflating: gpt-2-simple/gpt-2/.git/objects/pack/pack-b661491ab1eccbdc864e0f14cadbe68bf8df677a.idx
#    creating: gpt-2-simple/gpt-2/.git/logs/refs/heads/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/.git/logs/refs/._heads
#    creating: gpt-2-simple/gpt-2/.git/logs/refs/remotes/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/.git/logs/refs/._remotes
#   inflating: gpt-2-simple/gpt-2/.git/refs/heads/master
#    creating: gpt-2-simple/gpt-2/.git/refs/remotes/origin/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/.git/refs/remotes/._origin
#   inflating: gpt-2-simple/.git/logs/refs/heads/master
#    creating: gpt-2-simple/.git/logs/refs/remotes/origin/
#   inflating: __MACOSX/gpt-2-simple/.git/logs/refs/remotes/._origin
#   inflating: gpt-2-simple/.git/refs/remotes/origin/HEAD
#   inflating: gpt-2-simple/gpt-2/.git/logs/refs/heads/master
#    creating: gpt-2-simple/gpt-2/.git/logs/refs/remotes/origin/
#   inflating: __MACOSX/gpt-2-simple/gpt-2/.git/logs/refs/remotes/._origin
#   inflating: gpt-2-simple/gpt-2/.git/refs/remotes/origin/HEAD
#   inflating: gpt-2-simple/.git/logs/refs/remotes/origin/HEAD
#   inflating: gpt-2-simple/gpt-2/.git/logs/refs/remotes/origin/HEAD

# %%
# !pip3 install -r ./gpt-2-simple/requirements.txt
# Out:
# Collecting tensorflow==1.15.2
#   Downloading https://files.pythonhosted.org/packages/9a/d9/fd234c7bf68638423fb8e7f44af7fcfce3bcaf416b51e6d902391e47ec43/tensorflow-1.15.2-cp36-cp36m-manylinux2010_x86_64.whl (110.5MB)
#      |████████████████████████████████| 110.5MB 81kB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from -r ./gpt-2-simple/requirements.txt (line 2)) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from -r ./gpt-2-simple/requirements.txt (line 3)) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from -r ./gpt-2-simple/requirements.txt (line 4)) (4.41.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from -r ./gpt-2-simple/requirements.txt (line 5)) (1.18.5)
# Collecting toposort
#   Downloading https://files.pythonhosted.org/packages/e9/8a/321cd8ea5f4a22a06e3ba30ef31ec33bea11a3443eeb1d89807640ee6ed4/toposort-1.5-py2.py3-none-any.whl
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r ./gpt-2-simple/requirements.txt (line 1)) (1.12.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r ./gpt-2-simple/requirements.txt (line 1)) (0.9.0)
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 37.2MB/s
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 36.4MB/s
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r ./gpt-2-simple/requirements.txt (line 1)) (3.12.4)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r ./gpt-2-simple/requirements.txt (line 1)) (1.1.0)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r ./gpt-2-simple/requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r ./gpt-2-simple/requirements.txt (line 1)) (0.34.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r ./gpt-2-simple/requirements.txt (line 1)) (1.1.2)
# Collecting keras-applications>=1.0.8
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 5.0MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r ./gpt-2-simple/requirements.txt (line 1)) (1.30.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r ./gpt-2-simple/requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r ./gpt-2-simple/requirements.txt (line 1)) (0.8.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.2->-r ./gpt-2-simple/requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->-r ./gpt-2-simple/requirements.txt (line 3)) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->-r ./gpt-2-simple/requirements.txt (line 3)) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->-r ./gpt-2-simple/requirements.txt (line 3)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->-r ./gpt-2-simple/requirements.txt (line 3)) (2020.6.20)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2->-r ./gpt-2-simple/requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2->-r ./gpt-2-simple/requirements.txt (line 1)) (49.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2->-r ./gpt-2-simple/requirements.txt (line 1)) (3.2.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15.2->-r ./gpt-2-simple/requirements.txt (line 1)) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2->-r ./gpt-2-simple/requirements.txt (line 1)) (1.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.2->-r ./gpt-2-simple/requirements.txt (line 1)) (3.1.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7540 sha256=6ca71cfe0c9a8c40420ea755d43293877f2f7f006e1f87e656ac7facc509d79c
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.11.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Installing collected packages: tensorflow-estimator, tensorboard, gast, keras-applications, tensorflow, toposort
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorflow 2.3.0
#     Uninstalling tensorflow-2.3.0:
#       Successfully uninstalled tensorflow-2.3.0
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-1.15.0 tensorflow-1.15.2 tensorflow-estimator-1.15.1 toposort-1.5

# %%
cd gpt-2-simple/
# Out:
# /content/gpt-2-simple

# %%
# !python3 generate_text.py --flag_pretrain  true
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# if true 335M
# Downloading 335M model...
# Fetching checkpoint: 1.05Mit [00:00, 542Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 620Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 612Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.05Mit [00:00, 649Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 657Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 648Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 634Mit/s]
# 2020-08-05 16:55:30.184481: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2020-08-05 16:55:30.188049: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-08-05 16:55:30.188279: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x189b100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-08-05 16:55:30.188592: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-08-05 16:55:33.999771: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 154389504 exceeds 10% of system memory.
# Loading checkpoint gpt-2/models/124M/model-10
# 2020-08-05 16:55:35.341281: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 154389504 exceeds 10% of system memory.
# # can you tell me how much you will charge for your service? # how much will i pay for it? # can you tell me the price? # what will you charge? # what is its cost? # i have a dispute but need to know how much it will cost before I instruct you? # i am buying a​ factory house​​ and want to know how much you charge? # i am selling my business and want to know how much you charge? # i have been given a ​contract how much will it cost? # will there be any additional fees to your fee? # what are the costs to your services if i am not entitled to legal aid? # is it free to amend a will? # how much do you charge for will amendments? # how much do you charge to prepare a visa? # what are the costs for your services if i am not entitled to legal aid? # what is the cost of making a will if i am not entitled to legal aid? # i need a cost estimate for legal proceedings. # how much will legal proceedings cost overall? # how much do you charge for a new lease of a commercial property? # how much will it cost to prepare a new will? # how much will it cost to get advice on a personal injury? # i need advice on a a dispute how much will it cost? # how much do you charge for equity release? # i need help with a construction dispute but need to know what you charge? # how much is an employment tribunal going to cost? # how much does it cost if i want to claim against​ my employer? # what is the cost of taking my employer to court? # i am involved in a dispute​ how much would this cost? # how much will my dispute claim cost me? # how much does it cost to make a will? # do you charge for amending a will? # how much is will? # is a ​visa expensive to make? # how much does your fee cost to me? # will it cost me in the end? # how much do you charge for damages? # how much do you charge for damage to the building? # how much do you charge for damage to the building? # how much do you charge for damages if ​your work is done in a way that you would not be expected to do
# of your work?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  |<|endoftext|>It was an hour and a half before the first headliner of the NFL Draft.
#
# It was almost four years to the day since the Giants won their first Super Bowl, and before the Bears won their fifth with their first win since 2004.
# The time came for the Giants to take the Giants' first, and finally win it all, with a win that made it all the way to the first round.
# The Giants went over and over in the first round, picking up some pretty good picks, but also selecting the best of the best, and in the second round, the best of the best.
# And here's what we know so far, and we also know about the other candidates.
# We know that the Giants' first round picks were essentially handed out like this their first round picks, at almost exactly the same time.
# But it's a long way from the time when the Giants made their starting lineup, let alone the first round, when they were drafted.
# They were then cut by the Giants and drafted right back in the sixth round, or in the seventh round.
# And the Giants had to get the second pick in the third round, which was the best pick in the draft, and thus the best possible pick.
# And yet, their second round pick is already in the second round.
# The Giants' third round pick, meanwhile, is just in the fifth round, the pick that they would have been promised.
# And the fourth round pick, the pick that they are in the fifth round.
#
# And the fifth round pick, the pick they would have been promised, is in the sixth round.
# And in the seventh round, the pick they would have been promised, is in the eighth round.
# And the seventh round pick, the pick they would have been promised, is in the eighth round.
# So the Giants have no choice but to take the third or fourth round picks.
# They first made their picks in the sixth, and then they took the fifth or sixth picks in the seventh.
# And in the eighth round, the third and fourth picks are in the eighth round.
# And in the ninth round, the fourth and fifth picks are in the ninth round.
# And in
